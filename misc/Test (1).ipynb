# %%
import cv2
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt

from torchvision.transforms import ToTensor

# %matplotlib inline

# %%
im_p = '/home/zephyr/Desktop/Newcastle_University/11_FP_D/Dataset/WSSS4LUAD/1.training/1.training/436219-7159-52707-[1, 1, 0].png'

# %%
img = cv2.imread(im_p)

# %%
plt.imshow(img)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (241, 203, 3)

# %%
ten = ToTensor()(img)

# %%
ten.shape
# Out:
# torch.Size([3, 241, 203])

# %%
x = np.moveaxis(img, -1, 0)
x.shape
# Out:
# (3, 241, 203)

# %%
plt.imshow(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/zephyr/Desktop/Newcastle_University/11_FP_D/code/Test.ipynb Cell 8' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/zephyr/Desktop/Newcastle_University/11_FP_D/code/Test.ipynb#ch0000007?line=0'>1</a> plt.imshow(x)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:456, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     450 if len(args) > name_idx:
#     451     warn_deprecated(
#     452         since, message="Passing the %(name)s %(obj_type)s "
#     453         "positionally is deprecated since Matplotlib %(since)s; the "
#     454         "parameter will become keyword-only %(removal)s.",
#     455         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 456 return func(*args, **kwargs)
#
# ...

# %%
y = Image.open(im_p)
z = Image.open(im_p).convert('RGB')

# %%
plt.imshow(y)

# %%
type(y)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
np.asarray(y).shape
# Out:
# (241, 203, 3)

# %%
plt.imshow(z)
